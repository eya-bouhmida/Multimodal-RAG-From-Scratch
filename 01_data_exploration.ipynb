# %% [markdown]
# <a href="https://colab.research.google.com/github/eya-bouhmida/Multimodal-RAG-From-Scratch/blob/main/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/eya-bouhmida/Multimodal-RAG-From-Scratch.git
# %cd Multimodal-RAG-From-Scratch
# Out:
# Cloning into 'Multimodal-RAG-From-Scratch'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 27 (delta 7), reused 20 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 5.13 KiB | 5.13 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/Multimodal-RAG-From-Scratch

# %%
import shutil
shutil.rmtree('/content/Multimodal-RAG-From-Scratch/data')

os.symlink(
    '/content/drive/MyDrive/multimodal-rag-project/data',
    '/content/Multimodal-RAG-From-Scratch/data'
)

print(os.listdir('/content/Multimodal-RAG-From-Scratch/data/'))
# Out:
# ['raw']

# %%
print(os.listdir('/content/Multimodal-RAG-From-Scratch/data/raw/'))
# Out:
# ['pubmed_multimodal', 'has_fr', 'who_en']
